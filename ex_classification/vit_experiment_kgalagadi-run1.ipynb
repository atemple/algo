# %% [markdown]
# # Vision Transformer (ViT) Explained

# %% [markdown]
# ![vit-architecture.png](data:image/png;base64,...)

# %% [markdown]
# (1) The ViT Architecture is based on Transformer architecture which was originally proposed to text tasks as NLP. ViT uses only the Encoder part of the transformer to feed images into the network.
#
# (2) The images are breaking down into fixed size patches, for example 16x16 or 32x32. More patches means more simpler it is to train the networks as the patches themselves get smaller.
#
# (3) The patches are then unrolled (flattened) and sent for further processing into the network.
#
# (4) Unlike NNs the model has no idea about the position of the samples in the sequence, so each sample is a patch from the input image. The image is fed along with a positional embedding vector and into the encoder, letting the model to learn about the image structure.
#
# (5) There is also a special token at the start of the embedding vector.
#
# (6) Each image patch is first unrolled (flattened) into a big vector and gets multiplied with an embedding matrix which is also learnable, creating embedded patches. The embedded patches are combined with the positional embedding vector and that gets fed into the Tranformer.
#
# (7) With the only difference being, instead of a decoder the output from the encoder is passed directly into a Feed Forward Neural Network to obtain the classification output.

# %% [markdown]
# # Imports

# %%
pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 9.8 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.15.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import pandas as pd
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import model_from_json
import tensorflow_addons as tfa

# %% [markdown]
# # Download dataset

# %% [markdown]
# Mount Google drive and unzip the kgalagadi dataset to local folder. Keep the folder structure as original file.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !mkdir '/content/dataset'

# %%
# !unzip '/content/drive/MyDrive/datasets/lila.bc/KGA_S1.lila.zip' -d '/content/dataset'
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0121.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0122.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0123.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0124.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0125.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0126.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0127.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0128.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0129.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0130.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0131.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0132.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0133.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0134.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0135.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0136.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0137.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0138.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0139.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0140.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0141.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0142.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0143.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0144.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0145.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0146.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0147.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0148.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0149.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0150.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0151.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0152.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0153.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0154.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0155.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0156.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0157.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0158.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0159.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0160.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0161.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0162.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0163.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0164.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0165.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0166.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0167.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0168.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0169.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0170.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0171.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0172.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0173.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0174.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0175.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0176.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0177.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0178.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0179.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0180.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0181.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0182.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0183.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0184.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0185.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0186.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0187.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0188.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0189.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0190.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0191.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0192.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0193.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0194.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0195.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0196.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0197.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0198.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0199.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0201.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0202.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0203.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0204.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0205.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0206.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0207.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0208.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0209.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0210.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0211.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0212.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0213.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0214.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0215.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0216.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0217.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0218.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0219.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0220.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0221.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0222.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0223.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0224.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0225.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0226.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0227.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0228.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0229.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0230.JPG
#  extracting: /content/dataset/KGA_S1/B05/B05_R1/KGA_S1_B05_R1_IMAG0231.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0004.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0005.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0006.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0007.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0008.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0009.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0010.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0011.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0012.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0013.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0014.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0015.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0016.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0017.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0018.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0019.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0020.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0021.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0022.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0023.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0024.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0025.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0026.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0027.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0028.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0029.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0030.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0031.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0032.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0033.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0034.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0035.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0036.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0037.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0038.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0039.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0040.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0041.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0042.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0043.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0044.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0045.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0046.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0047.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0048.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0049.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0050.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0051.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0052.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0053.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0054.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0055.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0056.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0057.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0058.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0059.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0060.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0061.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0062.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0063.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0064.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0065.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0066.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0067.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0068.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0069.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0070.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0071.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0072.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0073.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0074.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0075.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0076.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0077.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0078.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0079.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0080.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0081.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0082.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0083.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0084.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0085.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0086.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0087.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0088.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0089.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0090.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0091.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0092.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0093.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0094.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0095.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0096.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0097.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0098.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0099.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0100.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0101.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0102.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0103.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0104.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0105.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0106.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0107.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0108.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0109.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0110.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0111.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0112.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0113.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0114.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0115.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0116.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0117.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0118.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0119.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0120.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0121.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0122.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0123.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0124.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0125.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0126.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0127.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0128.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0129.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0130.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0131.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0132.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0133.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0134.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0135.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0136.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0137.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0138.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0139.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0140.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0141.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0142.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0143.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0144.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0145.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0146.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0147.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0148.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0149.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0150.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0151.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0152.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0153.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0154.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0155.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0156.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0157.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0158.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0159.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0160.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0161.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0162.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0163.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0164.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0165.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0166.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0167.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0168.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0169.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0170.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0171.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0172.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0173.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0174.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0175.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0176.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0177.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0178.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0179.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0180.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0181.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0182.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0183.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0184.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0185.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0186.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0187.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0188.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0189.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0190.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0191.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0192.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0193.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0194.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0195.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0196.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0197.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0198.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0199.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0200.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0201.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0202.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0203.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0204.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0205.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0206.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0207.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0208.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0209.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0210.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0211.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0212.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0213.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0214.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0215.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0216.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0217.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0218.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0219.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0220.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0221.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0222.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0223.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0224.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0225.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0226.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0227.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0228.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0229.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0230.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0231.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0232.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0233.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0234.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0235.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0236.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0237.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0238.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0239.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0240.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0241.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0242.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0243.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0244.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0245.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0246.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0247.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0248.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0249.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0250.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0251.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0252.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0253.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0254.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0255.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0256.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0257.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0258.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0259.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0260.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0261.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0262.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0263.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0264.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0265.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0266.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0267.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0268.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0269.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0270.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0271.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0272.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0273.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0274.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0275.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0276.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0277.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0278.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0279.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0280.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0281.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0282.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0283.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0284.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0285.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0286.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0287.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0288.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0289.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0290.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0291.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0292.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0293.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0294.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0295.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0296.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0297.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0298.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0299.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0300.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0301.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0302.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0303.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0304.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0305.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0306.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0307.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0308.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0309.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0310.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0311.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0312.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0313.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0314.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0315.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0316.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0317.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0318.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0319.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0320.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0321.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0322.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0323.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0324.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0325.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0326.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0327.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0328.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0329.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0330.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0331.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0332.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0333.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0334.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0335.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0336.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0337.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0338.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0339.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0340.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0341.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0342.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0343.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0344.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0345.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0346.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0347.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0348.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0349.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0350.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0351.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0352.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0353.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0354.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0355.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0356.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0357.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0358.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0359.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0360.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0361.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0362.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0363.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0364.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0365.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0366.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0367.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0368.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0369.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0370.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0371.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0372.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0373.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0374.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0375.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0376.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0377.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0378.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0379.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0380.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0381.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0382.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0383.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0384.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0385.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0386.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0387.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0388.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0389.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0390.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0391.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0392.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0393.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0394.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0395.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0396.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0397.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0398.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0399.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0400.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0401.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0402.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0403.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0404.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0405.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0406.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0407.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0408.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0409.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0410.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0411.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0412.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0413.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0414.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0415.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0416.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0417.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0418.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0419.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0420.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0421.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0422.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0423.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0424.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0425.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0426.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0427.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0428.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0429.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0430.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0431.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0432.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0433.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0434.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0435.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0436.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0437.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0438.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0439.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0440.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0441.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0442.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0443.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0444.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0445.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0446.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0447.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0448.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0449.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0450.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0451.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0452.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0453.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0454.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0455.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0456.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0457.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0458.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0459.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0460.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0461.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0462.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0463.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0464.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0465.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0466.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0467.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0468.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0469.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0470.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0471.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0472.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0473.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0474.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0475.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0476.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0477.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0478.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0479.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0480.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0481.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0482.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0483.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0484.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0485.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0486.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0487.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0488.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0489.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0490.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0491.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0492.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0493.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0494.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0495.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0496.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0497.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0498.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0499.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0500.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0501.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0502.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0503.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0504.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0505.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0506.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0507.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0508.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0509.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0510.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0511.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0512.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0513.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0514.JPG
#  extracting: /content/dataset/KGA_S1/B06/B06_R1/KGA_S1_B06_R1_IMAG0515.JPG
# ...
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0429.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0430.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0431.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0432.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0433.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0434.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0435.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0436.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0437.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0438.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0439.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0440.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0441.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0442.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0443.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0444.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0445.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0446.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0447.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0448.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0449.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0450.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0451.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0452.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0453.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0454.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0455.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0456.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0457.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0458.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0459.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0460.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0461.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0462.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0463.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0464.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0465.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0466.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0467.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0468.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0469.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0470.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0471.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0472.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0473.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0474.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0475.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0476.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0477.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0478.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0479.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0480.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0481.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0482.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0483.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0484.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0485.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0486.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0487.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0488.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0489.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0490.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0491.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0492.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0493.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0494.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0495.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0496.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0497.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0498.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0499.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0500.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0501.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0502.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0503.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0504.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0505.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0506.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0507.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0508.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0509.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0510.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0511.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0512.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0513.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0514.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0515.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0516.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0517.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0518.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0519.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0520.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0521.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0522.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0523.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0524.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0525.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0526.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0527.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0528.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0529.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0530.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0531.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0532.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0533.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0534.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0535.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0536.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0537.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0538.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0539.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0540.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0541.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0542.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0543.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0544.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0545.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0546.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0547.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0548.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0549.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0550.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0551.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0552.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0553.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0554.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0555.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0556.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0557.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0558.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0559.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0560.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0561.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0562.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0563.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0564.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0565.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0566.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0567.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0568.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0569.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0570.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0571.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0572.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0573.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0574.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0575.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0576.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0577.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0578.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0579.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0580.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0581.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0582.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0583.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0584.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0585.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0586.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0587.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0588.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0589.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0590.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0591.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0592.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0593.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0594.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0595.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0596.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0597.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0598.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0599.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0600.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0601.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0602.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0603.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0604.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0605.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0606.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0607.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0608.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0609.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0610.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0611.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0612.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0613.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0614.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0615.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0616.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0617.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0618.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0619.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0620.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0621.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0622.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0623.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0624.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0625.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0626.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0627.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0628.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0629.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0630.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0631.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0632.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0633.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0634.JPG
#  extracting: /content/dataset/KGA_S1/B09/B09_R1/KGA_S1_B09_R1_IMAG0635.JPG

# %% [markdown]
# # Hyperparameters Setup

# %% [markdown]
# Defining some variables and model hyperparameters used by the experiment. All variables are in UPPER CASE to be facilitates the code understanding.

# %%
NUM_CLASSES = 31
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001
BATCH_SIZE = 256 # default 256
NUM_EPOCHS = 20 # change to 100
IMAGE_SIZE = 72  # We'll resize input images to this size
PATCH_SIZE = 6  # Size of the patches to be extract from the input images
INPUT_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2,
    PROJECTION_DIM,
]  # Size of the transformer layers
TRANSFORMER_LAYERS = 8
MLP_HEAD_UNITS = [2048, 1024]  # Size of the dense layers of the final classifier
CLASSES = [
  'aardvarkantbear', 'birdofprey', 'birdother', 'blank', 'bustardkori', 'caracal', 'catafricanwild', 'cheetah', \
  'duikercommongrey', 'eland', 'foxbateared', 'foxcape', 'gemsbokoryx', 'harecape', 'hartebeestred', 'honeybadger', \
  'human', 'hyenabrown', 'hyenaspotted', 'jackalblackbacked', 'kudu', 'leopard', 'lionfemale', 'meerkatsuricate', \
  'ostrich', 'porcupine', 'reptilesamphibians', 'rodent', 'secretarybird', 'steenbok', 'wildebeestblue'
]

# %% [markdown]
# # Dataset Setup

# %% [markdown]
# Copy kgalagadi CSV files to create a dataframe from all files. Remove nonexistent files to avoid warning and errors during the training process. Create train(88%), validation(10%) and test (2%) datasets to be used in the model.

# %% [markdown]
# ## Create dataframes

# %%
# !cp /content/drive/MyDrive/datasets/lila.bc/KGA_S1_report*.* -d /content/dataset

# %%
lila_repo = pd.read_csv('/content/dataset/KGA_S1_report_lila.csv', sep=',')
lila_inve = pd.read_csv('/content/dataset/KGA_S1_report_lila_image_inventory.csv', sep=',')

dataset = pd.merge(lila_repo, lila_inve, how="left", on="capture_id")
dataset = dataset.rename(columns={'question__species': 'label'})
dataset = dataset[dataset.columns.drop(list(dataset.filter(regex='question__')))]
dataset.image_path_rel = '/content/dataset/' + dataset.image_path_rel
image_path_rel = dataset.pop('image_path_rel')
dataset.insert(1, 'image_path_rel', image_path_rel)

dataset.head()
# Out:
#        capture_id  ... image_rank_in_capture
# 0  KGA_S1#A01#1#1  ...                     1
# 1  KGA_S1#A01#1#1  ...                     2
# 2  KGA_S1#A01#1#1  ...                     3
# 3  KGA_S1#A01#1#2  ...                     1
# 4  KGA_S1#A01#1#2  ...                     2
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Remove nonexistent files

# %%
# remove files that does not exist
is_f = []
for p in dataset.image_path_rel.values:
    if os.path.isfile(p):
        is_f.append(1)
    else:
        is_f.append(0)
dataset['is_f'] = is_f
dataset = dataset.loc[dataset.is_f == 1]
dataset.shape
# Out:
# (10267, 14)

# %% [markdown]
# ## Create datasets

# %%
# split the dataframe into train and test dataframes
train_df, test_df = train_test_split(dataset, test_size = 0.02, random_state = 42)

# %%
DF_DATASET = '/content/dataset'

# images generator
data_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                           validation_split = 0.1)

# load training and validating images from directory
train_set = data_gen.flow_from_dataframe(dataframe = train_df,
                                         x_col = 'image_path_rel',
                                         y_col = 'label',
                                         classes = CLASSES,
                                         subset = 'training',
                                         seed = 574,
                                         color_mode = 'rgb',
                                         shuffle = True,
                                         batch_size = BATCH_SIZE,
                                         target_size = (IMAGE_SIZE, IMAGE_SIZE),
                                         class_mode = 'categorical',
                                         validate_filenames = False)

valid_set = data_gen.flow_from_dataframe(dataframe = train_df,
                                         x_col = 'image_path_rel',
                                         y_col = 'label',
                                         classes = CLASSES,
                                         subset = 'validation',
                                         seed = 32,
                                         color_mode = 'rgb',
                                         shuffle = False,
                                         batch_size = BATCH_SIZE,
                                         target_size = (IMAGE_SIZE, IMAGE_SIZE),
                                         class_mode = 'categorical',
                                         validate_filenames = False)

test_set  = data_gen.flow_from_dataframe(dataframe = test_df,
                                         x_col = 'image_path_rel',
                                         y_col = 'label',
                                         classes = CLASSES,
                                         color_mode = 'rgb',
                                         shuffle = False,
                                         seed = 986,
                                         batch_size = BATCH_SIZE,
                                         target_size = (IMAGE_SIZE, IMAGE_SIZE),
                                         class_mode = 'categorical',
                                         validate_filenames = False)

STEP_SIZE_TRAIN = train_set.n // train_set.batch_size
STEP_SIZE_VALID = valid_set.n // valid_set.batch_size
# Out:
# Found 9055 non-validated image filenames belonging to 31 classes.
# Found 1006 non-validated image filenames belonging to 31 classes.
# Found 206 non-validated image filenames belonging to 31 classes.

# %% [markdown]
# ## Show image samples

# %%
# show image samples
images, labels = next(train_set)[:25]

fig, axes = plt.subplots(5, 5, figsize=(10, 10))
for img, label, ax in zip(images, labels, axes.flatten()):
    ax.imshow(img)
    idx = np.where(label == 1)[0]
    ax.set_xlabel(list(train_set.class_indices)[idx.item()])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Build ViT Model

# %% [markdown]
# Building a ViT model as described in ViT architecture. Defining input shape from the model. Adding data augmentation into before break down the images into fixed size patches. Adding a start token and unroll the patches. Adding L Transformer Block layers to the model. Feeding the vector into a final MLP layer.

# %% [markdown]
# ## Data Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ## Patches Image Creator

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %% [markdown]
# ### Display a Image Sample Patch

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))

images = next(train_set)[0][:1]
image = images[0]

plt.imshow(image, vmin=0, vmax=255)
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

patches = Patches(PATCH_SIZE)(resized_image)
print(f"Image size: {IMAGE_SIZE} X {IMAGE_SIZE}")
print(f"Patch size: {PATCH_SIZE} X {PATCH_SIZE}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (PATCH_SIZE, PATCH_SIZE, 3))
    plt.imshow(patch_img.numpy())
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %% [markdown]
# ## MLP

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Patch Encoder Layer

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# ## Create ViT Model

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # (2) Create patches.
    patches = Patches(PATCH_SIZE)(augmented)
    # (3, 4) Encode patches.
    encoded_patches = PatchEncoder(NUM_PATCHES, PROJECTION_DIM)(patches)

    # (6) Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units = TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units = MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits, name="vit_model")

    return model

# %%
# create classifier
vit_classifier = create_vit_classifier()
vit_classifier.summary()
# Out:
# Model: "vit_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 72, 72, 3)]  0           []
#
#  data_augmentation (Sequential)  (None, 72, 72, 3)   7           ['input_2[0][0]']
#
#  patches_2 (Patches)            (None, None, 108)    0           ['data_augmentation[1][0]']
#
#  patch_encoder_1 (PatchEncoder)  (None, 144, 64)     16192       ['patches_2[0][0]']
#
#  layer_normalization_17 (LayerN  (None, 144, 64)     128         ['patch_encoder_1[0][0]']
#  ormalization)
#
#  multi_head_attention_8 (MultiH  (None, 144, 64)     66368       ['layer_normalization_17[0][0]',
#  eadAttention)                                                    'layer_normalization_17[0][0]']
#
#  add_16 (Add)                   (None, 144, 64)      0           ['multi_head_attention_8[0][0]',
#                                                                   'patch_encoder_1[0][0]']
#
#  layer_normalization_18 (LayerN  (None, 144, 64)     128         ['add_16[0][0]']
#  ormalization)
#
#  dense_21 (Dense)               (None, 144, 128)     8320        ['layer_normalization_18[0][0]']
#
#  dropout_19 (Dropout)           (None, 144, 128)     0           ['dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 144, 64)      8256        ['dropout_19[0][0]']
#
#  dropout_20 (Dropout)           (None, 144, 64)      0           ['dense_22[0][0]']
#
#  add_17 (Add)                   (None, 144, 64)      0           ['dropout_20[0][0]',
#                                                                   'add_16[0][0]']
#
#  layer_normalization_19 (LayerN  (None, 144, 64)     128         ['add_17[0][0]']
#  ormalization)
#
#  multi_head_attention_9 (MultiH  (None, 144, 64)     66368       ['layer_normalization_19[0][0]',
#  eadAttention)                                                    'layer_normalization_19[0][0]']
#
#  add_18 (Add)                   (None, 144, 64)      0           ['multi_head_attention_9[0][0]',
#                                                                   'add_17[0][0]']
#
#  layer_normalization_20 (LayerN  (None, 144, 64)     128         ['add_18[0][0]']
#  ormalization)
#
#  dense_23 (Dense)               (None, 144, 128)     8320        ['layer_normalization_20[0][0]']
#
#  dropout_21 (Dropout)           (None, 144, 128)     0           ['dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 144, 64)      8256        ['dropout_21[0][0]']
#
#  dropout_22 (Dropout)           (None, 144, 64)      0           ['dense_24[0][0]']
#
#  add_19 (Add)                   (None, 144, 64)      0           ['dropout_22[0][0]',
#                                                                   'add_18[0][0]']
#
#  layer_normalization_21 (LayerN  (None, 144, 64)     128         ['add_19[0][0]']
#  ormalization)
#
#  multi_head_attention_10 (Multi  (None, 144, 64)     66368       ['layer_normalization_21[0][0]',
#  HeadAttention)                                                   'layer_normalization_21[0][0]']
#
#  add_20 (Add)                   (None, 144, 64)      0           ['multi_head_attention_10[0][0]',
#                                                                   'add_19[0][0]']
#
#  layer_normalization_22 (LayerN  (None, 144, 64)     128         ['add_20[0][0]']
#  ormalization)
#
#  dense_25 (Dense)               (None, 144, 128)     8320        ['layer_normalization_22[0][0]']
#
#  dropout_23 (Dropout)           (None, 144, 128)     0           ['dense_25[0][0]']
#
#  dense_26 (Dense)               (None, 144, 64)      8256        ['dropout_23[0][0]']
#
#  dropout_24 (Dropout)           (None, 144, 64)      0           ['dense_26[0][0]']
#
#  add_21 (Add)                   (None, 144, 64)      0           ['dropout_24[0][0]',
#                                                                   'add_20[0][0]']
#
#  layer_normalization_23 (LayerN  (None, 144, 64)     128         ['add_21[0][0]']
#  ormalization)
#
#  multi_head_attention_11 (Multi  (None, 144, 64)     66368       ['layer_normalization_23[0][0]',
#  HeadAttention)                                                   'layer_normalization_23[0][0]']
#
#  add_22 (Add)                   (None, 144, 64)      0           ['multi_head_attention_11[0][0]',
#                                                                   'add_21[0][0]']
#
#  layer_normalization_24 (LayerN  (None, 144, 64)     128         ['add_22[0][0]']
#  ormalization)
#
#  dense_27 (Dense)               (None, 144, 128)     8320        ['layer_normalization_24[0][0]']
#
#  dropout_25 (Dropout)           (None, 144, 128)     0           ['dense_27[0][0]']
#
#  dense_28 (Dense)               (None, 144, 64)      8256        ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)           (None, 144, 64)      0           ['dense_28[0][0]']
#
#  add_23 (Add)                   (None, 144, 64)      0           ['dropout_26[0][0]',
#                                                                   'add_22[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 144, 64)     128         ['add_23[0][0]']
#  ormalization)
#
#  multi_head_attention_12 (Multi  (None, 144, 64)     66368       ['layer_normalization_25[0][0]',
#  HeadAttention)                                                   'layer_normalization_25[0][0]']
#
#  add_24 (Add)                   (None, 144, 64)      0           ['multi_head_attention_12[0][0]',
#                                                                   'add_23[0][0]']
#
#  layer_normalization_26 (LayerN  (None, 144, 64)     128         ['add_24[0][0]']
#  ormalization)
#
#  dense_29 (Dense)               (None, 144, 128)     8320        ['layer_normalization_26[0][0]']
#
#  dropout_27 (Dropout)           (None, 144, 128)     0           ['dense_29[0][0]']
#
#  dense_30 (Dense)               (None, 144, 64)      8256        ['dropout_27[0][0]']
#
#  dropout_28 (Dropout)           (None, 144, 64)      0           ['dense_30[0][0]']
#
#  add_25 (Add)                   (None, 144, 64)      0           ['dropout_28[0][0]',
#                                                                   'add_24[0][0]']
#
#  layer_normalization_27 (LayerN  (None, 144, 64)     128         ['add_25[0][0]']
#  ormalization)
#
#  multi_head_attention_13 (Multi  (None, 144, 64)     66368       ['layer_normalization_27[0][0]',
#  HeadAttention)                                                   'layer_normalization_27[0][0]']
#
#  add_26 (Add)                   (None, 144, 64)      0           ['multi_head_attention_13[0][0]',
#                                                                   'add_25[0][0]']
#
#  layer_normalization_28 (LayerN  (None, 144, 64)     128         ['add_26[0][0]']
#  ormalization)
#
#  dense_31 (Dense)               (None, 144, 128)     8320        ['layer_normalization_28[0][0]']
#
#  dropout_29 (Dropout)           (None, 144, 128)     0           ['dense_31[0][0]']
#
#  dense_32 (Dense)               (None, 144, 64)      8256        ['dropout_29[0][0]']
#
#  dropout_30 (Dropout)           (None, 144, 64)      0           ['dense_32[0][0]']
#
#  add_27 (Add)                   (None, 144, 64)      0           ['dropout_30[0][0]',
#                                                                   'add_26[0][0]']
#
#  layer_normalization_29 (LayerN  (None, 144, 64)     128         ['add_27[0][0]']
#  ormalization)
#
#  multi_head_attention_14 (Multi  (None, 144, 64)     66368       ['layer_normalization_29[0][0]',
#  HeadAttention)                                                   'layer_normalization_29[0][0]']
#
#  add_28 (Add)                   (None, 144, 64)      0           ['multi_head_attention_14[0][0]',
#                                                                   'add_27[0][0]']
#
#  layer_normalization_30 (LayerN  (None, 144, 64)     128         ['add_28[0][0]']
#  ormalization)
#
#  dense_33 (Dense)               (None, 144, 128)     8320        ['layer_normalization_30[0][0]']
#
#  dropout_31 (Dropout)           (None, 144, 128)     0           ['dense_33[0][0]']
#
#  dense_34 (Dense)               (None, 144, 64)      8256        ['dropout_31[0][0]']
#
#  dropout_32 (Dropout)           (None, 144, 64)      0           ['dense_34[0][0]']
#
#  add_29 (Add)                   (None, 144, 64)      0           ['dropout_32[0][0]',
#                                                                   'add_28[0][0]']
#
#  layer_normalization_31 (LayerN  (None, 144, 64)     128         ['add_29[0][0]']
#  ormalization)
#
#  multi_head_attention_15 (Multi  (None, 144, 64)     66368       ['layer_normalization_31[0][0]',
#  HeadAttention)                                                   'layer_normalization_31[0][0]']
#
#  add_30 (Add)                   (None, 144, 64)      0           ['multi_head_attention_15[0][0]',
#                                                                   'add_29[0][0]']
#
#  layer_normalization_32 (LayerN  (None, 144, 64)     128         ['add_30[0][0]']
#  ormalization)
#
#  dense_35 (Dense)               (None, 144, 128)     8320        ['layer_normalization_32[0][0]']
#
#  dropout_33 (Dropout)           (None, 144, 128)     0           ['dense_35[0][0]']
#
#  dense_36 (Dense)               (None, 144, 64)      8256        ['dropout_33[0][0]']
#
#  dropout_34 (Dropout)           (None, 144, 64)      0           ['dense_36[0][0]']
#
#  add_31 (Add)                   (None, 144, 64)      0           ['dropout_34[0][0]',
#                                                                   'add_30[0][0]']
#
#  layer_normalization_33 (LayerN  (None, 144, 64)     128         ['add_31[0][0]']
#  ormalization)
#
#  flatten_1 (Flatten)            (None, 9216)         0           ['layer_normalization_33[0][0]']
#
#  dropout_35 (Dropout)           (None, 9216)         0           ['flatten_1[0][0]']
#
#  dense_37 (Dense)               (None, 2048)         18876416    ['dropout_35[0][0]']
#
#  dropout_36 (Dropout)           (None, 2048)         0           ['dense_37[0][0]']
#
#  dense_38 (Dense)               (None, 1024)         2098176     ['dropout_36[0][0]']
#
#  dropout_37 (Dropout)           (None, 1024)         0           ['dense_38[0][0]']
#
#  dense_39 (Dense)               (None, 31)           31775       ['dropout_37[0][0]']
#
# ==================================================================================================
# Total params: 21,688,294
# Trainable params: 21,688,287
# Non-trainable params: 7
# __________________________________________________________________________________________________

# %% [markdown]
# # Run Experiment

# %% [markdown]
# Run experiment by compiling the model with the AdamW optimizer, Categorical Crossentropy loss and specific metrics (accuracy and top-5 accuracy). Train the model with pre-defined epochs and batch sizes. Evaluate and predict the model with some test images.

# %% [markdown]
# ## Compile and Train Model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    model.fit(x = train_set,
              batch_size = BATCH_SIZE,
              epochs = NUM_EPOCHS,
              validation_data = valid_set,
              callbacks = checkpoint_callback
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x = train_set)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return model

# %%
model = run_experiment(vit_classifier)
# Out:
# Epoch 1/20
# 36/36 [==============================] - 693s 19s/step - loss: 3.3760 - accuracy: 0.6540 - top-5-accuracy: 0.9192 - val_loss: 3.3127 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9672
# Epoch 2/20
# 36/36 [==============================] - 657s 18s/step - loss: 3.2574 - accuracy: 0.7601 - top-5-accuracy: 0.9551 - val_loss: 3.1935 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9672
# Epoch 3/20
# 36/36 [==============================] - 632s 18s/step - loss: 3.1406 - accuracy: 0.7668 - top-5-accuracy: 0.9557 - val_loss: 3.0761 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9592
# Epoch 4/20
# 36/36 [==============================] - 638s 18s/step - loss: 3.0248 - accuracy: 0.7668 - top-5-accuracy: 0.9569 - val_loss: 2.9611 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 5/20
# 36/36 [==============================] - 644s 18s/step - loss: 2.9137 - accuracy: 0.7668 - top-5-accuracy: 0.9575 - val_loss: 2.8486 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 6/20
# 36/36 [==============================] - 640s 18s/step - loss: 2.8044 - accuracy: 0.7668 - top-5-accuracy: 0.9581 - val_loss: 2.7385 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 7/20
# 36/36 [==============================] - 647s 18s/step - loss: 2.6964 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 2.6309 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 8/20
# 36/36 [==============================] - 642s 18s/step - loss: 2.5920 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 2.5260 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 9/20
# 36/36 [==============================] - 630s 18s/step - loss: 2.4908 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 2.4234 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 10/20
# 36/36 [==============================] - 634s 18s/step - loss: 2.3939 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 2.3245 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 11/20
# 36/36 [==============================] - 639s 18s/step - loss: 2.2982 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 2.2291 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 12/20
# 36/36 [==============================] - 637s 18s/step - loss: 2.2079 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 2.1370 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 13/20
# 36/36 [==============================] - 643s 18s/step - loss: 2.1196 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 2.0486 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 14/20
# 36/36 [==============================] - 638s 18s/step - loss: 2.0379 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 1.9643 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 15/20
# 36/36 [==============================] - 637s 18s/step - loss: 1.9564 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 1.8840 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 16/20
# 36/36 [==============================] - 637s 18s/step - loss: 1.8822 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 1.8074 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 17/20
# 36/36 [==============================] - 634s 18s/step - loss: 1.8094 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 1.7349 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 18/20
# 36/36 [==============================] - 634s 18s/step - loss: 1.7427 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 1.6666 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 19/20
# 36/36 [==============================] - 635s 18s/step - loss: 1.6787 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 1.6025 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# Epoch 20/20
# 36/36 [==============================] - 643s 18s/step - loss: 1.6182 - accuracy: 0.7668 - top-5-accuracy: 0.9580 - val_loss: 1.5423 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9702
# 36/36 [==============================] - 583s 16s/step - loss: 3.3143 - accuracy: 0.7668 - top-5-accuracy: 0.9562
# Test accuracy: 76.68%
# Test top 5 accuracy: 95.62%

# %% [markdown]
# ## Evaluate Model

# %%
eval_res = model.evaluate(test_set, steps = len(test_set), verbose = 1, return_dict = True)
# Out:
# 1/1 [==============================] - 13s 13s/step - loss: 3.3153 - accuracy: 0.7718 - top-5-accuracy: 0.9466

# %%
# show results
print('Evaluate:')
print('---------------')
print("ACCURACY:",(eval_res['accuracy']))
print("TOP 5 ACCURACY:",(eval_res['top-5-accuracy']))
print("LOSS:",(eval_res['loss']))
# Out:
# Evaluate:
# ---------------
# ACCURACY: 0.7718446850776672
# TOP 5 ACCURACY: 0.946601927280426
# LOSS: 3.315251350402832

# %% [markdown]
# ## Predict Images

# %%
# predict classes from test dataset
test_set.reset()
Y_pred = model.predict(test_set, steps = test_set.n // test_set.batch_size + 1)
y_pred = np.argmax(Y_pred, axis=1)

true_classes = len(test_set.class_indices)
class_values = list(test_set.class_indices.values())
class_labels = list(test_set.class_indices.keys())

print('Classification Report')
print(classification_report(test_set.classes, y_pred))

print('Confusion Matrix')
confusionmatrix = confusion_matrix(test_set.classes, y_pred, labels = class_values)
plt.figure(figsize = (10, 10))
sns.heatmap(confusionmatrix, cmap = 'Blues', annot = True, cbar = True)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         5
#            3       0.77      1.00      0.87       159
#            8       0.00      0.00      0.00         3
#            9       0.00      0.00      0.00         2
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00        26
#           15       0.00      0.00      0.00         1
#           17       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00         5
#           28       0.00      0.00      0.00         1
#
#     accuracy                           0.77       206
#    macro avg       0.07      0.09      0.08       206
# weighted avg       0.60      0.77      0.67       206
#
# Confusion Matrix
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# serialize weights to HDF5
model.save_weights('/content/drive/MyDrive/datasets/lila.bc/vit-model-weights-e20.h5')
print('Saved model to disk')

# !cp /content/drive/MyDrive/datasets/lila.bc/model.h5 -d /content/dataset
# model = vit_classifier.load_weights('/content/dataset/model.h5')
# print("Loaded model from disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Predict Specific Image

# %%
# get specific image from test dataset
row = test_df.loc[test_df['label'] == 'gemsbokoryx']

image_to_test = row.image_path_rel.values[0]
label = row.label.values[0]

from keras.preprocessing import image
image_to_test = image.load_img(image_to_test,
                              target_size = (IMAGE_SIZE, IMAGE_SIZE))
image_to_test = image.img_to_array(image_to_test)
image_to_test /= 255
image_to_test = np.expand_dims(image_to_test, axis = 0)

# %%
# predict class from image
test_set.reset()
Y_pred = model.predict(image_to_test)
y_test_cat = keras.utils.to_categorical(Y_pred, NUM_CLASSES)

sorting = (-Y_pred).argsort()
sorted = sorting[0][:3]

for value in sorted:
  predicted_label = CLASSES[value]
  prob = (Y_pred[0][value]) * 100
  prob = "%.2f" % round(prob,2)
  print("I have %s%% sure that it belongs to %s." % (prob, predicted_label))
# Out:
# I have 7.41% sure that it belongs to blank.
# I have 7.02% sure that it belongs to gemsbokoryx.
# I have -0.34% sure that it belongs to birdother.

# %%
Y_pred
# Out:
# array([[-0.07082997, -0.07157309, -0.00343575,  0.07413451, -0.06333484,
#         -0.07155795, -0.07074429, -0.07040986, -0.0695862 , -0.07292248,
#         -0.0707766 , -0.06738321,  0.07019276, -0.07019532, -0.07139429,
#         -0.07235267, -0.07217757, -0.07133044, -0.07054402, -0.06787883,
#         -0.07063252, -0.06970719, -0.07143719, -0.07192095, -0.06558289,
#         -0.0714018 , -0.07098873, -0.07007844, -0.06840937, -0.06712842,
#         -0.07005476]], dtype=float32)
